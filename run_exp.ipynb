# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/SynchronousRL
# !dir
# Out:
# /content/drive/MyDrive/SynchronousRL
# data				 run_exp.ipynb
# data_LessStrict			 run.py
# data_Strict			 Smalldata_LessStrict
# func.py				 Smalldata_Strict
# __init__.py			 Smallresult_AttFalse_EmbFalse_Strict
# model				 Smallresult_AttFalse_EmbTrue_Strict
# preproc_data.py			 Smallresult_AttTrue_EmbTrue_LessStrict
# __pycache__			 Smallresult_AttTrue_EmbTrue_Strict
# README.txt			 src
# result_AttFalse_EmbFalse_Strict  util.py
# result_AttFalse_EmbTrue_Strict	 viz
# result_AttTrue_EmbTrue_Strict

# %%
# !python run.py
# Out:
# Took 185.361 seconds
# Took 164.050 seconds
# Took 178.473 seconds
# Took 184.406 seconds
# Took 164.823 seconds
# Took 180.332 seconds
# Took 636.022 seconds
# Loss: -8.356 / Average Reward: 70.288:  16% 163/1000 [01:36<07:52,  1.77it/s]
